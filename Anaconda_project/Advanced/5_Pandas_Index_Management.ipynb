# %%
# Importing Libraries
from tqdm.notebook import trange, tqdm
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
#Inspect the data frame
#Index on the left does not have a name and everything is off to the right.
df.sample(5)
# Out:
#             job_title_short  \
# 219643  Senior Data Analyst
# 416561         Data Analyst
# 599538        Data Engineer
# 607103         Data Analyst
# 572986        Data Engineer
#
#                                                 job_title  \
# 219643                       Senior Business Data Analyst
# 416561                     Junior Data Analyst to Kavall!
# 599538  Data Engineer  (Apply only if you have more th...
# 607103                                  Fuel Data Analyst
# 572986                                  Data Engineer F/H
#
#                          job_location                  job_via  \
# 219643                    Orlando, FL             via LinkedIn
# 416561              Stockholm, Sweden            via WREG Jobs
# 599538    Hyderabad, Telangana, India             via LinkedIn
# 607103                 Nairobi, Kenya             via MyJobMag
# 572986  Saint-André-lez-Lille, France  via Emplois Trabajo.org
#
#        job_schedule_type  job_work_from_home         search_location  \
# 219643         Full-time               False  Florida, United States
# 416561         Full-time               False                  Sweden
# 599538         Full-time               False                   India
# 607103         Full-time               False                   Kenya
# 572986         Full-time               False                  France
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 219643 2023-01-19 22:18:58                  False                  True
# 416561 2023-01-11 16:32:46                   True                 False
# 599538 2023-07-12 09:12:29                   True                 False
# 607103 2023-11-29 09:29:17                   True                 False
# 572986 2023-11-08 09:37:56                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 219643  United States        None              NaN              NaN
# 416561         Sweden        None              NaN              NaN
# 599538          India        None              NaN              NaN
# 607103          Kenya        None              NaN              NaN
# 572986         France        None              NaN              NaN
#
#                 company_name  \
# 219643  Travel + Leisure Co.
# 416561         Academic Work
# 599538   Apidel Technologies
# 607103         Kenya Airways
# 572986              DECIDEOM
#
#                                                job_skills  \
# 219643    ['sql', 'sas', 'sas', 'python', 'r', 'tableau']
# 416561                 ['go', 'express', 'excel', 'flow']
# 599538  ['java', 'mongo', 'sql', 'scala', 'mongodb', '...
# 607103                                               None
# 572986  ['sql', 'python', 'c', 'snowflake', 'gcp', 'aw...
#
#                                           job_type_skills
# 219643  {'analyst_tools': ['sas', 'tableau'], 'program...
# 416561  {'analyst_tools': ['excel'], 'other': ['flow']...
# 599538  {'cloud': ['azure', 'databricks'], 'databases'...
# 607103                                               None
# 572986  {'cloud': ['snowflake', 'gcp', 'aws', 'azure']...

# %%
#Check the index
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
#Check the name of the index and name it
df.index.name = "job_index"

# %%
#Check if the name saved
df.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
#
#                            job_location             job_via job_schedule_type  \
# job_index
# 0                         Watertown, CT     via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                       Berlin, Germany        via LinkedIn         Full-time
# 3                       San Antonio, TX   via Diversity.com         Full-time
# 4                        Washington, DC  via Clearance Jobs         Full-time
#
#            job_work_from_home       search_location     job_posted_date  \
# job_index
# 0                       False  Texas, United States 2023-06-16 13:44:15
# 1                       False                Mexico 2023-01-14 13:18:07
# 2                       False               Germany 2023-10-10 13:14:55
# 3                       False  Texas, United States 2023-07-04 13:01:41
# 4                       False                 Sudan 2023-08-07 14:29:36
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 1                          False                 False         Mexico
# 2                          False                 False        Germany
# 3                           True                 False  United States
# 4                          False                 False          Sudan
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                None              NaN              NaN
# 1                None              NaN              NaN
# 2                None              NaN              NaN
# 3                None              NaN              NaN
# 4                None              NaN              NaN
#
#                            company_name  \
# job_index
# 0                  Boehringer Ingelheim
# 1            Hewlett Packard Enterprise
# 2              ALPHA Augmented Services
# 3          Southwest Research Institute
# 4                       Kristina Daniel
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 1          ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2          ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4          ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 1          {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4          {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
#Attritubes data type
df.index.dtype
# Out:
# dtype('int64')

# %%
#Reset_index()
#Filtering the df for USA jobs

df_usa = df[df['job_country']== 'United States']

# %%
df_usa.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...
