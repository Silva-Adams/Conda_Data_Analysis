# %%
# Importing Libraries
from tqdm.notebook import trange, tqdm
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original

# %%
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_altered["salary_year_avg"].median()
median_salary
# Out:
# 115000.0

# %%
df_altered["salary_year_avg"] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
#Create df_Original again to get a different object ID
dataset = load_dataset('lukebarousse/data_jobs')
df_original2 = dataset['train'].to_pandas()

# %%
#Create Df_altered again using copy method to get a data frame with a different ID
df_altered2 = df_original2.copy()

# %%
#Calculate the median salary again using the copied Data Frame
madian_salary = df_altered2['salary_year_avg'].median()

df_altered2['salary_year_avg'] = df_altered2['salary_year_avg'].fillna(median_salary)

df_altered2.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
#Pivot Tables
